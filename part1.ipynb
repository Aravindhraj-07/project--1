# %% [markdown]
# importing

# %%
import joblib
import numpy as np

model = joblib.load("house_price_model.pkl")

sample = np.array([[2000,3,2,1,2015]])   # example features

prediction = model.predict(sample)

print(prediction)
# Out:
# c:\Users\Sakthi\OneDrive\Desktop\microsoft projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[140], line 8
#       4 model = joblib.load("house_price_model.pkl")
#       6 sample = np.array([[2000,3,2,1,2015]])   # example features
# ----> 8 prediction = model.predict(sample)
#      10 print(prediction)
#
# File c:\Users\Sakthi\OneDrive\Desktop\microsoft projects\.venv\Lib\site-packages\sklearn\ensemble\_forest.py:1065, in ForestRegressor.predict(self, X)
#    1063 check_is_fitted(self)
#    1064 # Check data
# -> 1065 X = self._validate_X_predict(X)
#    1067 # Assign chunk of trees to jobs
#    1068 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# ...
